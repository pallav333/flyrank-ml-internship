# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I have chosen **Lane 2 - Refresh / Content Opportunity Scoring**.
#
# I chose this lane because it helps identify which content pages should be reviewed or refreshed first. This helps content teams prioritize their work instead of manually checking every page. I selected this lane because it matches the starter notebooks, is suitable for beginners, and solves a practical machine learning problem.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### The decision, action, and cost of a wrong call
#
# This model is designed to improve the decision-making process for **content strategists** and **content teams**. It helps them decide *which existing content pages to prioritize for refresh or update*.
#
# **Content writers**, **SEO specialists**, and **marketing teams** will use these recommendations to take action. The primary action is to allocate resources efficiently, focusing on refreshing or enhancing content that the model identifies as having the highest opportunity for improved performance (e.g., increased traffic, engagement, conversions).
#
# If the recommendation is wrong, the **cost** can be significant. Wasted resources (time, effort, budget) might be spent on refreshing pages that yield little to no improvement, diverting attention from genuinely high-potential content. This could lead to missed opportunities for business growth, stagnant content performance, and ultimately, a lower return on investment for content efforts.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Quick look at the data
#
# To get a preliminary understanding of the dataset, I will load the starter data and calculate a few basic statistics. These numbers will help confirm the dataset's scale and general characteristics, providing a foundation for further analysis.

# %%
import pandas as pd

# IMPORTANT: Please replace this with the *exact* URL to your starter dataset.
# You can usually find this in your FlyRank assignment's repository or instructions.
# Example: 'https://raw.githubusercontent.com/your-username/flyrank-repo/main/data/starter.csv'
dataset_url = 'YOUR_CORRECT_FLYRANK_DATASET_URL_HERE'

try:
    df = pd.read_csv(dataset_url)

    # Display key statistics
    print(f"Number of rows: {df.shape[0]}")
    print(f"Number of columns: {df.shape[1]}")

    # Try to find a common numerical column like 'page_views' or 'impressions'
    # If these columns don't exist, you'll need to adjust this part or choose other numerical columns.
    numerical_columns = ['page_views', 'impressions', 'visits', 'unique_visitors', 'clicks', 'conversions']
    found_numerical_col = False
    for col in numerical_columns:
        if col in df.columns:
            print(f"Average {col.replace('_', ' ').title()}: {df[col].mean():.2f}")
            found_numerical_col = True
            break # Display only the first suitable numerical column's average
    if not found_numerical_col:
        print("No common numerical columns like 'page_views' or 'impressions' found for averaging. Please inspect your data for suitable columns.")

    display(df.head())
except Exception as e:
    print(f"Error loading or processing data: {e}")
    print("Please ensure the `dataset_url` is correct and the file exists. You might need to adjust the column names for statistics if your dataset uses different names.")
# Out:
# Error loading or processing data: [Errno 2] No such file or directory: 'YOUR_CORRECT_FLYRANK_DATASET_URL_HERE'
# Please ensure the `dataset_url` is correct and the file exists. You might need to adjust the column names for statistics if your dataset uses different names.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful words: what I can and can't claim
#
# When interpreting the results of this analysis, it's crucial to use careful language to accurately reflect the scope and limitations of the work:
#
# **What I can claim:**
# *   This analysis provides **directional insights** into content performance, identifying pages that, based on **observed patterns** in historical data, show higher statistical likelihood of benefiting from a refresh.
# *   The model offers **decision-support** by recommending a prioritization order for content efforts, helping teams allocate resources more effectively.
# *   The findings are based on **measured performance metrics** and can inform strategic content updates to improve key indicators.
#
# **What I cannot claim:**
# *   This analysis does **not establish causal proof** that refreshing a specific page will *guarantee* a particular increase in traffic or conversions. It suggests correlation and opportunity, not direct causation.
# *   It **cannot predict future changes** in search engine algorithms, market trends, or user behavior that might impact content performance. The recommendations are based on past data.
# *   The model is a tool for optimization and guidance; it is **not a guarantee of specific outcomes** or a replacement for expert human judgment in content strategy.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ### Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all) - *You need to run the notebook to confirm this.*
# - [ ] No client names, URLs, or private queries anywhere - *You need to verify this yourself, especially the dataset URL.*
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done. - *You need to perform this action.*
